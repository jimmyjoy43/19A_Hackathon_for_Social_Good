# %%
import pandas as pd
import bs4 as bs 
import numpy as np
import os
from PIL import Image
import codecs, json
import pandas as pd

from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
% matplotlib inline

# %% [markdown]
# The test set of tweets only includes tweets from the past month filtered by #23F + #Venezuela

# %% [markdown]
# ## Import JSON file from tweetscraper package

# %%
with codecs.open('test.json', 'r', 'utf-8') as f:
    tweets = json.load(f, encoding='utf-8')

list_tweets = [list(elem.values()) for elem in tweets]
list_columns = list(tweets[0].keys())
df = pd.DataFrame(list_tweets, columns=list_columns)

# %%
df
# Out:
#                fullname                                               html  \
# 0   Gisela Berrizbeitia  <p class="TweetTextSize js-tweet-text tweet-te...
# 1       FREITESNOTICIAS  <p class="TweetTextSize js-tweet-text tweet-te...
# 2  Las Hermanas Mirabal  <p class="TweetTextSize js-tweet-text tweet-te...
# 3                  Nena  <p class="TweetTextSize js-tweet-text tweet-te...
# 4                  Nena  <p class="TweetTextSize js-tweet-text tweet-te...
# 5              Nathalia  <p class="TweetTextSize js-tweet-text tweet-te...
# 6           Jorge Jerez  <p class="TweetTextSize js-tweet-text tweet-te...
#
#                     id  likes  replies  retweets  \
# 0  1117772618118123522      0        0         0
# 1  1118558148728643585      0        1         0
# 2  1118330748723818497      0        0         0
# 3  1118316047789170688      1        0         2
# 4  1118316043884220422      0        0         1
# 5  1113154939482722304      2        0         0
# ...

# %% [markdown]
# ## Import and clean CSV file from Exporter.py

# %% [markdown]
# These queries were ran from the command line to download tweets: <br>
# <br>
#
# python Exporter.py --querysearch "#MillonesContraLaDictadura" --since 2017-04-20 --until 2017-06-20 <br>
# python Exporter.py --querysearch "#MillonesContraLaDictadura" --since 2017-05-20 --until 2017-05-23 <br>
# python Exporter.py --querysearch "#21Ene" --since 2019-01-21 --until 2019-01-24 <br>
# python Exporter.py --querysearch "#23Feb" --since 2019-02-23 --until 2019-02-26 <br>
# python Exporter.py --querysearch "#24Mayo" --since 2017-05-24 --until 2017-05-27 <br>
# python Exporter.py --querysearch "#19VzlaEnLaCalle" --since 2017-04-19 --until 2017-04-22 <br>
# python Exporter.py --querysearch "#ElLlanito" --since 2016-06-09 --until 2016-06-12 <br>
# python Exporter.py --querysearch "#YoReportoEl26O" --since 2016-10-26 --until 2016-10-29 <br>
# python Exporter.py --querysearch "#12F" --since 2014-02-12 --until 2014-02-15 <br>
# python Exporter.py --querysearch "#19F" --since 2014-02-19 --until 2014-02-22 <br>

# %%
import re
directory = '****'
os.chdir(directory/'clean')

for filename in os.listdir(directory):
    
    if filename.endswith(".csv"):
        with open (filename, 'r',encoding="utf8") as f:
            content = f.read()

        content_new = re.sub(';\s', r'-', content, flags = re.M)

        filename2 = os.path.splitext(filename)[0]
        new_name = filename2 + mod + ".csv"

        output_file = open(new_name, "w")

        output_file.write(content_new)

# %%
path = directory+'/clean'
os.chdir(path)
df2 = pd.read_csv('12F_2014_02_12_to_2014_02_15_mod.csv', sep=';',error_bad_lines=False)
# Out:
# b'Skipping line 14699: expected 10 fields, saw 12\nSkipping line 15499: expected 10 fields, saw 12\nSkipping line 28221: expected 10 fields, saw 11\n'

# %%
df2.head()
# Out:
#           username              date  retweets  favorites  \
# 0   javierelbasset  2014-02-14 18:59         6          1
# 1   racinyricardor  2014-02-14 18:58         1          0
# 2  elyelyrodriguez  2014-02-14 18:58         0          0
# 3   anatetrujilloa  2014-02-14 18:58         0          0
# 4        Rafabap24  2014-02-14 18:58         0          0
#
#                                                 text  geo      mentions  \
# 0  Encontrado en la protesta del Cafetal. Está en...  NaN    @MaryT_SMT
# 1  Nahh... que san valentin ni que coño. Hay gent...  NaN           NaN
# 2  “@MaryT_SMT: Encontrado en la protesta del Caf...  NaN  @MaryT_SMT @
# 3  Quieren cerrar la puerta de Metro Altamira. # 12f  NaN           NaN
# 4  La hora que termina la concentracion del # 12F...  NaN           NaN
#
#   hashtags            id                                          permalink
# 0      # #  4.344771e+17  https://twitter.com/javierelbasset/status/4344...
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64176 entries, 0 to 64175
# Data columns (total 10 columns):
# username     64176 non-null object
# date         64176 non-null object
# retweets     64176 non-null int64
# favorites    64176 non-null int64
# text         64176 non-null object
# geo          1097 non-null object
# mentions     27999 non-null object
# hashtags     63078 non-null object
# id           63079 non-null float64
# permalink    63079 non-null object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 4.9+ MB

# %%
df3 = pd.read_csv('21Ene_2019_01_21_to_2019_01_24_mod.csv', sep=';',error_bad_lines=False)

# %%
df3.head()
# Out:
#         username              date  retweets  favorites  \
# 0     DolarToday  2019-01-23 18:44        15         40
# 1     sophie_Gon  2019-01-23 18:35         0          2
# 2  prolibertadve  2019-01-23 18:27         0          0
# 3     DolarToday  2019-01-23 18:24        31         38
# 4        elay_yo  2019-01-23 18:24         0          1
#
#                                                 text  geo mentions   hashtags  \
# 0  Vecinos de San Bernardino llegan a Cotiza para...  NaN      NaN        # #
# 1  Unidos con Venezuela # FuerzaVenezuela # 21Ene...  NaN      NaN      # # #
# 2  RT alfredoromero: # 23Ene Hasta ahora son más ...  NaN      NaN  # # # # #
# 3  Vecinos de San Bernardino llegan a Cotiza para...  NaN      NaN        # #
# 4  # 21Ene Venezolanos en Santa Cruz, # Bolivia r...  NaN        @    # # # #
#
#              id                                          permalink
# 0  1.088221e+18  https://twitter.com/DolarToday/status/10882209...
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23838 entries, 0 to 23837
# Data columns (total 10 columns):
# username     23838 non-null object
# date         23838 non-null object
# retweets     23838 non-null int64
# favorites    23838 non-null int64
# text         23838 non-null object
# geo          4 non-null object
# mentions     7548 non-null object
# hashtags     23834 non-null object
# id           23834 non-null float64
# permalink    23834 non-null object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 1.8+ MB
