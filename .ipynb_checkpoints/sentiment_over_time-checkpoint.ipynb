# %%
import pandas as pd
import bs4 as bs 
import numpy as np
import os
from PIL import Image
import codecs, json
import pandas as pd

# %%
curr_dir = os.getcwd()
tar_dir = curr_dir + '/data/sentiment'

# %%
file = os.listdir(tar_dir)[0]
path = tar_dir + '/' + file

# %%
df = pd.read_csv(path, sep=',',error_bad_lines=False)
df.head()
# Out:
#    Unnamed: 0         username              date  retweets  favorites  \
# 0           0       VpaJimenez  2019-02-25 18:59         0          1
# 1           1      ValenciaHoy  2019-02-25 18:59         2          0
# 2           2  GabrielParraDic  2019-02-25 18:59         0          0
# 3           3        emejiasva  2019-02-25 18:57         2          1
# 4           4       JHONNILSON  2019-02-25 18:56         0          0
#
#                                                 text  geo mentions  \
# 0  El sábado # 23Feb fue un día en el cual el mun...  NaN      NaN
# 1  Alcalde Johan Castañeda lideró jornadas deport...  NaN      NaN
# 2  # Repost @ 2001online (get_repost) ・・・ Otro mi...  NaN        @
# 3  El  Guernica " venezolano.. fotografías. # 23F...  NaN      NaN
# 4  QUE ALGUIEN ME DIGA # yosoyvoluntarioxvenezuel...  NaN      NaN
#
#           hashtags            id  \
# 0              # #  1.100184e+18
# 1              # #  1.100184e+18
# 2          # # # #  1.100184e+18
# 3                #  1.100183e+18
# 4  # # # # # # # #  1.100183e+18
#
#                                            permalink  \
# 0  https://twitter.com/VpaJimenez/status/11001836...
# 1  https://twitter.com/ValenciaHoy/status/1100183...
# 2  https://twitter.com/GabrielParraDic/status/110...
# 3  https://twitter.com/emejiasva/status/110018292...
# 4  https://twitter.com/JHONNILSON/status/11001828...
#
#                                              retweet  \
# 0  El sábado # 23Feb fue un día en el cual el mun...
# 1  Alcalde Johan Castañeda lideró jornadas deport...
# 2  # Repost @ 2001online (get_repost) ・・・ Otro mi...
# 3  El  Guernica " venezolano.. fotografías. # 23F...
# 4  QUE ALGUIEN ME DIGA # yosoyvoluntarioxvenezuel...
#
#                                           clean_text language  sentiment
# 0  El sábado  fue un día en el cual el mundo pudo...       es   0.657344
# 1  Alcalde Johan Castañeda lideró jornadas deport...       es   0.535592
# 2     get_repost      Otro militar venezolano cru...       es   0.601500
# 3         El  Guernica   venezolano   fotografías          es   0.505551
# 4                       QUE ALGUIEN ME DIGA                es   0.308206

# %%
# change date to datetime object
df['date'] = pd.to_datetime(df.date)

# %%
df.head()
# Out:
#    Unnamed: 0         username                date  retweets  favorites  \
# 0           0       VpaJimenez 2019-02-25 18:59:00         0          1
# 1           1      ValenciaHoy 2019-02-25 18:59:00         2          0
# 2           2  GabrielParraDic 2019-02-25 18:59:00         0          0
# 3           3        emejiasva 2019-02-25 18:57:00         2          1
# 4           4       JHONNILSON 2019-02-25 18:56:00         0          0
#
#                                                 text  geo mentions  \
# 0  El sábado # 23Feb fue un día en el cual el mun...  NaN      NaN
# 1  Alcalde Johan Castañeda lideró jornadas deport...  NaN      NaN
# 2  # Repost @ 2001online (get_repost) ・・・ Otro mi...  NaN        @
# 3  El  Guernica " venezolano.. fotografías. # 23F...  NaN      NaN
# 4  QUE ALGUIEN ME DIGA # yosoyvoluntarioxvenezuel...  NaN      NaN
#
#           hashtags            id  \
# 0              # #  1.100184e+18
# 1              # #  1.100184e+18
# 2          # # # #  1.100184e+18
# 3                #  1.100183e+18
# 4  # # # # # # # #  1.100183e+18
#
#                                            permalink  \
# 0  https://twitter.com/VpaJimenez/status/11001836...
# 1  https://twitter.com/ValenciaHoy/status/1100183...
# 2  https://twitter.com/GabrielParraDic/status/110...
# 3  https://twitter.com/emejiasva/status/110018292...
# 4  https://twitter.com/JHONNILSON/status/11001828...
#
#                                              retweet  \
# 0  El sábado # 23Feb fue un día en el cual el mun...
# 1  Alcalde Johan Castañeda lideró jornadas deport...
# 2  # Repost @ 2001online (get_repost) ・・・ Otro mi...
# 3  El  Guernica " venezolano.. fotografías. # 23F...
# 4  QUE ALGUIEN ME DIGA # yosoyvoluntarioxvenezuel...
#
#                                           clean_text language  sentiment
# 0  El sábado  fue un día en el cual el mundo pudo...       es   0.657344
# 1  Alcalde Johan Castañeda lideró jornadas deport...       es   0.535592
# 2     get_repost      Otro militar venezolano cru...       es   0.601500
# 3         El  Guernica   venezolano   fotografías          es   0.505551
# 4                       QUE ALGUIEN ME DIGA                es   0.308206

# %%
# set datetime object to index
df = df.set_index('date')

# %%
avg_sent_per_week = df.date.resample('W').mean()
