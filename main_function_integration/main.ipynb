# %% [markdown]
# ### The purpose of this notebook is to return a plot of sentiment and tweet count over time so that incipient violence can be monitored. <br>
# The notebook takes a user input in the form of: <br> 1) a hashtag related to a protest <br> 2) the number of previous hours to include in the search (e.g., entering 24 would return the previous 24 hours) <br>
# <br>Once the user updates these parameters, the following cells can be ran which call scripts to access the twitter API and get recent tweets, analyze sentiment through the Microsoft Text Analytics platform, and make the plot.

# %%
# ignore warnings for purpose of demo
import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# Change user input below. The hashtag should be a string format and the time_period should be numeric.

# %%
###### user input #######
hashtag = '#OperacionLibertad '         
time_period = 24 # search previous hours

# %% [markdown]
# Run the script to grab recent tweets with new search parameters.

# %%
# run the script to get the tweets
import get_tweets  

filename = get_tweets.get_recent_tweets(hashtag, time_period)
# Out:
# Found existing data

# %% [markdown]
# Analyze the sentiment of the tweets.

# %%
# run the script to get the sentiment score
import get_sentiment

df = get_sentiment.score_sentiment(filename)
# Out:
# /home/alex/Documents/Hackathon/19A_Hackathon_for_Social_Good/main_function_integration/get_sentiment.py:119: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   tweets = tweets[tweets['clean_text'].str.contains('([a-zA-Z]+)', regex=True)]

# %% [markdown]
# Plot to sentiment and tweet count over time for a given hashtag.

# %%
# run script to get plots
import get_plots

plt = get_plots.sentiment(df,hashtag)
# Out:
# /home/alex/Documents/Hackathon/19A_Hackathon_for_Social_Good/main_function_integration/get_plots.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['datetime'] = pd.to_datetime(df.datetime)
# /home/alex/anaconda3/envs/hackathon/lib/python3.6/site-packages/pandas/core/arrays/datetimes.py:1172: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   "will drop timezone information.", UserWarning)
# /home/alex/anaconda3/envs/hackathon/lib/python3.6/site-packages/pandas/core/arrays/datetimes.py:1172: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   "will drop timezone information.", UserWarning)
