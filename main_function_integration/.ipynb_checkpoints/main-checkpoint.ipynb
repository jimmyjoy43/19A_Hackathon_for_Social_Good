# %%
# run the script to get the tweets
import get_tweets

hashtag = '#1May'         
time_period = 0.2 # hours     

filename = get_tweets.get_recent_tweets(hashtag, time_period)
# Out:
# Reached start time

# %%
filename
# Out:
# 'tweet_files/search_results_2019-05-02T21_46_50+00_00.txt'

# %%
import pandas as pd
df = pd.read_csv(filename)

# %%
import get_sentiment
df = get_sentiment.score_sentiment(filename)
# Out:
# https://westcentralus.api.cognitive.microsoft.com/text/analytics/v2.1/languages
# https://westcentralus.api.cognitive.microsoft.com/text/analytics/v2.1/sentiment
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-35b95181e11b> in <module>()
#       1 import get_sentiment
# ----> 2 df = get_sentiment.score_sentiment(filename)
#
# ~/Google Drive/19A_Hackathon_for_Social_Good/main_function_integration/get_sentiment.py in score_sentiment(filename)
#     117     #clean tweet text
#     118     tweets['clean_text'] = tweets.apply(clean_tweet, axis=1)
# --> 119     tweets = tweets[tweets['clean_text'].str.contains('([a-zA-Z]+)', regex=True)]
#     120
#     121     chunk_dfs = []
#
# AttributeError: 'TextFileReader' object has no attribute 'apply'

# %%
def clean_tweet(row):
    text = re.sub('Retweeted.*\):','',row['full_text'])
    text = re.sub('(http.*$)','',text)
    text = re.sub('(pic.twitter.*$)','',text)
    text = re.sub('([@#][\w_-]+)','',text)
    text = re.sub('([@] [^ ]+)','', text)
    text = re.sub('([#] [^ ]+)','', text)
    text = re.sub('[^\w]', ' ', text)
    text = re.sub('(['  '.*])', ' ', text)
    return text

# %%
tweets = pd.read_csv(filename,error_bad_lines=False)

# %%
tweets.head()
# Out:
#    Unnamed: 0  contributors coordinates                      created_at  \
# 0           0           NaN         NaN  Thu May 02 21:46:50 +0000 2019
# 1           1           NaN         NaN  Thu May 02 21:46:01 +0000 2019
# 2           2           NaN         NaN  Thu May 02 21:45:00 +0000 2019
# 3           3           NaN         NaN  Thu May 02 21:43:43 +0000 2019
# 4           4           NaN         NaN  Thu May 02 21:43:03 +0000 2019
#
#   display_text_range                                           entities  \
# 0           [0, 277]  {'hashtags': [{'text': '1May', 'indices': [61,...
# 1            [0, 92]  {'hashtags': [{'text': '1May', 'indices': [63,...
# 2           [0, 112]  {'hashtags': [{'text': '1May', 'indices': [82,...
# 3           [0, 182]  {'hashtags': [{'text': '1may', 'indices': [118...
# 4           [0, 110]  {'hashtags': [{'text': '1May', 'indices': [81,...
#
#                                    extended_entities  favorite_count  \
# 0  {'media': [{'id': 1124067713918353410, 'id_str...               0
# 1  {'media': [{'id': 1124067446325903361, 'id_str...               0
# 2                                                NaN               2
# 3  {'media': [{'id': 1124066892895928321, 'id_str...               0
# 4  {'media': [{'id': 1124066797341368320, 'id_str...               0
#
#    favorited                                          full_text  ...  \
# 0      False  Vicepdte. sectorial @psuvaristobulo:"La movili...  ...
# 1      False  Gustavo Duque: Salud Chacao atendió a 69 perso...  ...
# 2      False  Nueve heridos por perdigones y más de 40 lesio...  ...
# 3      False  Nosotros los Jóvenes ADecos de la Seccional Cu...  ...
# 4      False  ¡DICTADURA CRIMINAL! Balance de detenidos y he...  ...
#
#   possibly_sensitive  quoted_status  quoted_status_id quoted_status_id_str  \
# 0              False            NaN               NaN                  NaN
# 1              False            NaN               NaN                  NaN
# 2              False            NaN               NaN                  NaN
# 3              False            NaN               NaN                  NaN
# 4              False            NaN               NaN                  NaN
#
#    retweet_count  retweeted  \
# 0              0      False
# 1              0      False
# 2              2      False
# 3              0      False
# 4              0      False
#
#                                               source  truncated  \
# 0  <a href="http://twitter.com/download/android" ...      False
# 1  <a href="http://twitter.com" rel="nofollow">Tw...      False
# 2  <a href="https://about.twitter.com/products/tw...      False
# 3  <a href="https://mobile.twitter.com" rel="nofo...      False
# 4  <a href="https://dlvrit.com/" rel="nofollow">d...      False
#
#                                                 user  \
# 0  {'id': 884816972, 'id_str': '884816972', 'name...
# 1  {'id': 2400260346, 'id_str': '2400260346', 'na...
# 2  {'id': 2828470096, 'id_str': '2828470096', 'na...
# 3  {'id': 532479710, 'id_str': '532479710', 'name...
# 4  {'id': 972138986562088961, 'id_str': '97213898...
#
#                     datetime
# 0  2019-05-02 21:46:50+00:00
# 1  2019-05-02 21:46:01+00:00
# 2  2019-05-02 21:45:00+00:00
# 3  2019-05-02 21:43:43+00:00
# 4  2019-05-02 21:43:03+00:00
#
# [5 rows x 32 columns]
